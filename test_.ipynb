# %%
from pylabrobot.liquid_handling.backends import EVOBackend

# %%
from pylabrobot.liquid_handling.backends.tecan.EVO_backend import LiHa, RoMa, PnP


lh1 = LiHa(None, "C1")
roma = RoMa(None, "W1")
pnp = PnP(None, "W5")
evo = EVOBackend(arms=[RoMa, LiHa, PnP])
arm1: LiHa = evo.arms[0]
arm2 = evo.arms[1]
arm3 = evo.arms[2]
# evo.arms_configured()
# arm3 = evo.arms[2]
# print(evo.roma)
print(arm1, arm2, arm3, sep='\n')
