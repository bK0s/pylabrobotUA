# %%
from pylabrobot.liquid_handling import LiquidHandler
from pylabrobot.liquid_handling.backends import LiquidHandlerChatterboxBackend
from pylabrobot.visualizer.visualizer import Visualizer
from pylabrobot.resources.tecan import EVO200Deck
from pylabrobot.resources.tube_rack import TubeRack

# %%
from pylabrobot.resources.coordinate import Coordinate

# evo = Evo_backend()
lh = LiquidHandler(backend=LiquidHandlerChatterboxBackend(), deck=EVO200Deck(origin=Coordinate(0,0,0)))
await lh.setup()
vis = Visualizer(resource=lh)
await vis.setup()
# Out:
# Setting up the liquid handler.
# Resource deck was assigned to the liquid handler.
# Resource wash_station was assigned to the liquid handler.
# Websocket server started at http://127.0.0.1:2121
# File server started at http://127.0.0.1:1337 . Open this URL in your browser.

# %%
from pylabrobot.resources import (
    MP_3Pos_Flat, #Tecan part no. 10612624
    Washstation_2Grid_Trough_DiTi, #Tecan part no. 10650037
    DiTi_3Pos, #Tecan part no. 10613022
    MP_4Pos_flat, #Tecan part no. 30013061
    MP_3Pos, #Tecan part no. 10612604
    DiTi_1000ul_CL_Filter_LiHa, #unsure if correct tip
    Microplate_96_Well #unsure if correct wellplate
)

# %%
# from pylabrobot.resources.tecan.tube_carrier import
from pylabrobot.resources.tecan.tube_carrier import tecan_tube_carrier_16, test_tube


flat_carrier_1 = MP_3Pos_Flat(name="Flat Carrier 1")
flat_carrier_2 = MP_3Pos_Flat(name="Flat Carrier 2")
washstation = Washstation_2Grid_Trough_DiTi(name="Wash Station")
tip_carrier = DiTi_3Pos(name="Disposable Tip Carrier")
flat_carrier_1[0]= well_rack0 = Microplate_96_Well(name="well_0")
flat_carrier_1[1]= well_rack1 = Microplate_96_Well(name="well_1")
flat_carrier_1[2]= well_rack2 = Microplate_96_Well(name="well_2")
flat_carrier_2[0]= well_rack3 = Microplate_96_Well(name="well_3")
flat_carrier_2[1]= well_rack4 = Microplate_96_Well(name="well_4")
flat_carrier_2[2]= well_rack5 = Microplate_96_Well(name="well_5")
tip_carrier[0]= tip_rack0 = DiTi_1000ul_CL_Filter_LiHa(name="tips_0")
tip_carrier[1]= tip_rack1 = DiTi_1000ul_CL_Filter_LiHa(name="tips_1")
tip_carrier[2]= tip_rack2 = DiTi_1000ul_CL_Filter_LiHa(name="tips_2")
centri_bucket_car = MP_4Pos_flat(name="Centrifuge Bucket Carrier")
regrip = MP_3Pos(name="Regrip")

# TUBES and Tube Carriers

# tube_carrier = tecan_tube_carrier_16("tube carrier")
# for i in range(16):
#     tube_carrier[i] = test_tube(f"tube{i}")

# %%
from pylabrobot.resources.coordinate import Coordinate


lh.get_resource("wash_station").unassign()

lh.deck.assign_child_resource(flat_carrier_1, rails=22)
lh.deck.assign_child_resource(flat_carrier_2, rails=28)
lh.deck.assign_child_resource(washstation, rails=38)
lh.deck.assign_child_resource(tip_carrier, rails=41)
lh.deck.assign_child_resource(centri_bucket_car, rails=48)
lh.deck.assign_child_resource(regrip, rails=61)
# lh.deck.assign_child_resource(tube_carrier, rails=12)
for i in range(10):
    lh.deck.assign_child_resource(tecan_tube_carrier_16(f"tube_carrier_{i}"), rails=i+12)
    tube_carrier = lh.get_resource(f"tube_carrier_{i}")
    for j in range(16):
        tube_carrier[j] = test_tube(f"test_tube_{i}_{j}")
# Out:
# Resource wash_station was unassigned from the liquid handler.
# Resource Flat Carrier 1 was assigned to the liquid handler.
# Resource Flat Carrier 2 was assigned to the liquid handler.
# Resource Wash Station was assigned to the liquid handler.
# Resource Disposable Tip Carrier was assigned to the liquid handler.
# Resource Centrifuge Bucket Carrier was assigned to the liquid handler.
# Resource Regrip was assigned to the liquid handler.
# Resource tube_carrier_0 was assigned to the liquid handler.
# Resource test_tube_0_0 was assigned to the liquid handler.
# Resource test_tube_0_1 was assigned to the liquid handler.
# Resource test_tube_0_2 was assigned to the liquid handler.
# Resource test_tube_0_3 was assigned to the liquid handler.
# Resource test_tube_0_4 was assigned to the liquid handler.
# Resource test_tube_0_5 was assigned to the liquid handler.
# Resource test_tube_0_6 was assigned to the liquid handler.
# Resource test_tube_0_7 was assigned to the liquid handler.
# Resource test_tube_0_8 was assigned to the liquid handler.
# Resource test_tube_0_9 was assigned to the liquid handler.
# Resource test_tube_0_10 was assigned to the liquid handler.
# Resource test_tube_0_11 was assigned to the liquid handler.
# Resource test_tube_0_12 was assigned to the liquid handler.
# Resource test_tube_0_13 was assigned to the liquid handler.
# Resource test_tube_0_14 was assigned to the liquid handler.
# Resource test_tube_0_15 was assigned to the liquid handler.
# Resource tube_carrier_1 was assigned to the liquid handler.
# Resource test_tube_1_0 was assigned to the liquid handler.
# Resource test_tube_1_1 was assigned to the liquid handler.
# Resource test_tube_1_2 was assigned to the liquid handler.
# Resource test_tube_1_3 was assigned to the liquid handler.
# Resource test_tube_1_4 was assigned to the liquid handler.
# Resource test_tube_1_5 was assigned to the liquid handler.
# Resource test_tube_1_6 was assigned to the liquid handler.
# Resource test_tube_1_7 was assigned to the liquid handler.
# Resource test_tube_1_8 was assigned to the liquid handler.
# Resource test_tube_1_9 was assigned to the liquid handler.
# Resource test_tube_1_10 was assigned to the liquid handler.
# Resource test_tube_1_11 was assigned to the liquid handler.
# Resource test_tube_1_12 was assigned to the liquid handler.
# Resource test_tube_1_13 was assigned to the liquid handler.
# Resource test_tube_1_14 was assigned to the liquid handler.
# Resource test_tube_1_15 was assigned to the liquid handler.
# Resource tube_carrier_2 was assigned to the liquid handler.
# Resource test_tube_2_0 was assigned to the liquid handler.
# Resource test_tube_2_1 was assigned to the liquid handler.
# Resource test_tube_2_2 was assigned to the liquid handler.
# Resource test_tube_2_3 was assigned to the liquid handler.
# Resource test_tube_2_4 was assigned to the liquid handler.
# Resource test_tube_2_5 was assigned to the liquid handler.
# Resource test_tube_2_6 was assigned to the liquid handler.
# Resource test_tube_2_7 was assigned to the liquid handler.
# Resource test_tube_2_8 was assigned to the liquid handler.
# Resource test_tube_2_9 was assigned to the liquid handler.
# Resource test_tube_2_10 was assigned to the liquid handler.
# Resource test_tube_2_11 was assigned to the liquid handler.
# Resource test_tube_2_12 was assigned to the liquid handler.
# Resource test_tube_2_13 was assigned to the liquid handler.
# Resource test_tube_2_14 was assigned to the liquid handler.
# Resource test_tube_2_15 was assigned to the liquid handler.
# Resource tube_carrier_3 was assigned to the liquid handler.
# Resource test_tube_3_0 was assigned to the liquid handler.
# Resource test_tube_3_1 was assigned to the liquid handler.
# Resource test_tube_3_2 was assigned to the liquid handler.
# Resource test_tube_3_3 was assigned to the liquid handler.
# Resource test_tube_3_4 was assigned to the liquid handler.
# Resource test_tube_3_5 was assigned to the liquid handler.
# Resource test_tube_3_6 was assigned to the liquid handler.
# Resource test_tube_3_7 was assigned to the liquid handler.
# Resource test_tube_3_8 was assigned to the liquid handler.
# Resource test_tube_3_9 was assigned to the liquid handler.
# Resource test_tube_3_10 was assigned to the liquid handler.
# Resource test_tube_3_11 was assigned to the liquid handler.
# Resource test_tube_3_12 was assigned to the liquid handler.
# Resource test_tube_3_13 was assigned to the liquid handler.
# Resource test_tube_3_14 was assigned to the liquid handler.
# Resource test_tube_3_15 was assigned to the liquid handler.
# Resource tube_carrier_4 was assigned to the liquid handler.
# Resource test_tube_4_0 was assigned to the liquid handler.
# Resource test_tube_4_1 was assigned to the liquid handler.
# Resource test_tube_4_2 was assigned to the liquid handler.
# Resource test_tube_4_3 was assigned to the liquid handler.
# Resource test_tube_4_4 was assigned to the liquid handler.
# Resource test_tube_4_5 was assigned to the liquid handler.
# Resource test_tube_4_6 was assigned to the liquid handler.
# Resource test_tube_4_7 was assigned to the liquid handler.
# Resource test_tube_4_8 was assigned to the liquid handler.
# Resource test_tube_4_9 was assigned to the liquid handler.
# Resource test_tube_4_10 was assigned to the liquid handler.
# Resource test_tube_4_11 was assigned to the liquid handler.
# Resource test_tube_4_12 was assigned to the liquid handler.
# Resource test_tube_4_13 was assigned to the liquid handler.
# Resource test_tube_4_14 was assigned to the liquid handler.
# Resource test_tube_4_15 was assigned to the liquid handler.
# Resource tube_carrier_5 was assigned to the liquid handler.
# Resource test_tube_5_0 was assigned to the liquid handler.
# Resource test_tube_5_1 was assigned to the liquid handler.
# Resource test_tube_5_2 was assigned to the liquid handler.
# Resource test_tube_5_3 was assigned to the liquid handler.
# Resource test_tube_5_4 was assigned to the liquid handler.
# Resource test_tube_5_5 was assigned to the liquid handler.
# Resource test_tube_5_6 was assigned to the liquid handler.
# Resource test_tube_5_7 was assigned to the liquid handler.
# Resource test_tube_5_8 was assigned to the liquid handler.
# Resource test_tube_5_9 was assigned to the liquid handler.
# Resource test_tube_5_10 was assigned to the liquid handler.
# Resource test_tube_5_11 was assigned to the liquid handler.
# Resource test_tube_5_12 was assigned to the liquid handler.
# Resource test_tube_5_13 was assigned to the liquid handler.
# Resource test_tube_5_14 was assigned to the liquid handler.
# Resource test_tube_5_15 was assigned to the liquid handler.
# Resource tube_carrier_6 was assigned to the liquid handler.
# Resource test_tube_6_0 was assigned to the liquid handler.
# Resource test_tube_6_1 was assigned to the liquid handler.
# Resource test_tube_6_2 was assigned to the liquid handler.
# Resource test_tube_6_3 was assigned to the liquid handler.
# Resource test_tube_6_4 was assigned to the liquid handler.
# Resource test_tube_6_5 was assigned to the liquid handler.
# Resource test_tube_6_6 was assigned to the liquid handler.
# Resource test_tube_6_7 was assigned to the liquid handler.
# Resource test_tube_6_8 was assigned to the liquid handler.
# Resource test_tube_6_9 was assigned to the liquid handler.
# Resource test_tube_6_10 was assigned to the liquid handler.
# Resource test_tube_6_11 was assigned to the liquid handler.
# Resource test_tube_6_12 was assigned to the liquid handler.
# Resource test_tube_6_13 was assigned to the liquid handler.
# Resource test_tube_6_14 was assigned to the liquid handler.
# Resource test_tube_6_15 was assigned to the liquid handler.
# Resource tube_carrier_7 was assigned to the liquid handler.
# Resource test_tube_7_0 was assigned to the liquid handler.
# Resource test_tube_7_1 was assigned to the liquid handler.
# Resource test_tube_7_2 was assigned to the liquid handler.
# Resource test_tube_7_3 was assigned to the liquid handler.
# Resource test_tube_7_4 was assigned to the liquid handler.
# Resource test_tube_7_5 was assigned to the liquid handler.
# Resource test_tube_7_6 was assigned to the liquid handler.
# Resource test_tube_7_7 was assigned to the liquid handler.
# Resource test_tube_7_8 was assigned to the liquid handler.
# Resource test_tube_7_9 was assigned to the liquid handler.
# Resource test_tube_7_10 was assigned to the liquid handler.
# Resource test_tube_7_11 was assigned to the liquid handler.
# Resource test_tube_7_12 was assigned to the liquid handler.
# Resource test_tube_7_13 was assigned to the liquid handler.
# Resource test_tube_7_14 was assigned to the liquid handler.
# Resource test_tube_7_15 was assigned to the liquid handler.
# Resource tube_carrier_8 was assigned to the liquid handler.
# Resource test_tube_8_0 was assigned to the liquid handler.
# Resource test_tube_8_1 was assigned to the liquid handler.
# Resource test_tube_8_2 was assigned to the liquid handler.
# Resource test_tube_8_3 was assigned to the liquid handler.
# Resource test_tube_8_4 was assigned to the liquid handler.
# Resource test_tube_8_5 was assigned to the liquid handler.
# Resource test_tube_8_6 was assigned to the liquid handler.
# Resource test_tube_8_7 was assigned to the liquid handler.
# Resource test_tube_8_8 was assigned to the liquid handler.
# Resource test_tube_8_9 was assigned to the liquid handler.
# Resource test_tube_8_10 was assigned to the liquid handler.
# Resource test_tube_8_11 was assigned to the liquid handler.
# Resource test_tube_8_12 was assigned to the liquid handler.
# Resource test_tube_8_13 was assigned to the liquid handler.
# Resource test_tube_8_14 was assigned to the liquid handler.
# Resource test_tube_8_15 was assigned to the liquid handler.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 14
#      12 # lh.deck.assign_child_resource(tube_carrier, rails=12)
#      13 for i in range(10):
# ---> 14     lh.deck.assign_child_resource(tecan_tube_carrier_16(f"tube_carrier_{i}"), rails=i+12)
#      15     tube_carrier = lh.get_resource(f"tube_carrier_{i}")
#      16     for j in range(16):
#
# File ~/Documents/School/Research Related/Ritchie Group/TECAN/PLR/pylabrobot/pylabrobot/resources/tecan/tecan_decks.py:124, in TecanDeck.assign_child_resource(self, resource, location, reassign, rails, replace)
#     111     # A resource is not allowed to overlap with another resource. Resources overlap when a
#     112     # corner of one resource is inside the boundaries other resource.
#     113     if (
#     114       og_x <= resource_location.x < og_x + og_resource.get_absolute_size_x()
#     115       or og_x
#    (...)    122       < og_y + og_resource.get_absolute_size_y()
#     123     ):
# --> 124       raise ValueError(
#     125         f"Location {resource_location} is already occupied by resource "
#     126         f"'{og_resource.name}'."
#     127       )
#     129 return super().assign_child_resource(resource, location=resource_location)
#
# ValueError: Location Coordinate(500.000, 038.000, 000.000) is already occupied by resource 'Flat Carrier 1'.

# %%
lh.summary()
# Out:
# Rail     Resource                   Type                Coordinates (mm)
# ===============================================================================================
# (12) ├── tube_carrier_0             TecanTubeCarrier    Coordinate(275.000, 038.000, 000.000)
#      │   ├── test_tube_0_0          Tube                Coordinate(278.000, 053.000, 011.200)
#      │   ├── test_tube_0_1          Tube                Coordinate(278.000, 071.800, 011.200)
#      │   ├── test_tube_0_2          Tube                Coordinate(278.000, 090.600, 011.200)
#      │   ├── test_tube_0_3          Tube                Coordinate(278.000, 109.400, 011.200)
#      │   ├── test_tube_0_4          Tube                Coordinate(278.000, 128.200, 011.200)
#      │   ├── test_tube_0_5          Tube                Coordinate(278.000, 147.000, 011.200)
#      │   ├── test_tube_0_6          Tube                Coordinate(278.000, 165.800, 011.200)
#      │   ├── test_tube_0_7          Tube                Coordinate(278.000, 184.600, 011.200)
#      │   ├── test_tube_0_8          Tube                Coordinate(278.000, 203.400, 011.200)
#      │   ├── test_tube_0_9          Tube                Coordinate(278.000, 222.200, 011.200)
#      │   ├── test_tube_0_10         Tube                Coordinate(278.000, 241.000, 011.200)
#      │   ├── test_tube_0_11         Tube                Coordinate(278.000, 259.800, 011.200)
#      │   ├── test_tube_0_12         Tube                Coordinate(278.000, 278.600, 011.200)
#      │   ├── test_tube_0_13         Tube                Coordinate(278.000, 297.400, 011.200)
#      │   ├── test_tube_0_14         Tube                Coordinate(278.000, 316.200, 011.200)
#      │   ├── test_tube_0_15         Tube                Coordinate(278.000, 335.000, 011.200)
#      │
# (13) ├── tube_carrier_1             TecanTubeCarrier    Coordinate(300.000, 038.000, 000.000)
#      │   ├── test_tube_1_0          Tube                Coordinate(303.000, 053.000, 011.200)
#      │   ├── test_tube_1_1          Tube                Coordinate(303.000, 071.800, 011.200)
#      │   ├── test_tube_1_2          Tube                Coordinate(303.000, 090.600, 011.200)
#      │   ├── test_tube_1_3          Tube                Coordinate(303.000, 109.400, 011.200)
#      │   ├── test_tube_1_4          Tube                Coordinate(303.000, 128.200, 011.200)
#      │   ├── test_tube_1_5          Tube                Coordinate(303.000, 147.000, 011.200)
#      │   ├── test_tube_1_6          Tube                Coordinate(303.000, 165.800, 011.200)
#      │   ├── test_tube_1_7          Tube                Coordinate(303.000, 184.600, 011.200)
#      │   ├── test_tube_1_8          Tube                Coordinate(303.000, 203.400, 011.200)
#      │   ├── test_tube_1_9          Tube                Coordinate(303.000, 222.200, 011.200)
#      │   ├── test_tube_1_10         Tube                Coordinate(303.000, 241.000, 011.200)
#      │   ├── test_tube_1_11         Tube                Coordinate(303.000, 259.800, 011.200)
#      │   ├── test_tube_1_12         Tube                Coordinate(303.000, 278.600, 011.200)
#      │   ├── test_tube_1_13         Tube                Coordinate(303.000, 297.400, 011.200)
#      │   ├── test_tube_1_14         Tube                Coordinate(303.000, 316.200, 011.200)
#      │   ├── test_tube_1_15         Tube                Coordinate(303.000, 335.000, 011.200)
#      │
# (14) ├── tube_carrier_2             TecanTubeCarrier    Coordinate(325.000, 038.000, 000.000)
#      │   ├── test_tube_2_0          Tube                Coordinate(328.000, 053.000, 011.200)
#      │   ├── test_tube_2_1          Tube                Coordinate(328.000, 071.800, 011.200)
#      │   ├── test_tube_2_2          Tube                Coordinate(328.000, 090.600, 011.200)
#      │   ├── test_tube_2_3          Tube                Coordinate(328.000, 109.400, 011.200)
#      │   ├── test_tube_2_4          Tube                Coordinate(328.000, 128.200, 011.200)
#      │   ├── test_tube_2_5          Tube                Coordinate(328.000, 147.000, 011.200)
#      │   ├── test_tube_2_6          Tube                Coordinate(328.000, 165.800, 011.200)
#      │   ├── test_tube_2_7          Tube                Coordinate(328.000, 184.600, 011.200)
#      │   ├── test_tube_2_8          Tube                Coordinate(328.000, 203.400, 011.200)
#      │   ├── test_tube_2_9          Tube                Coordinate(328.000, 222.200, 011.200)
#      │   ├── test_tube_2_10         Tube                Coordinate(328.000, 241.000, 011.200)
#      │   ├── test_tube_2_11         Tube                Coordinate(328.000, 259.800, 011.200)
#      │   ├── test_tube_2_12         Tube                Coordinate(328.000, 278.600, 011.200)
#      │   ├── test_tube_2_13         Tube                Coordinate(328.000, 297.400, 011.200)
#      │   ├── test_tube_2_14         Tube                Coordinate(328.000, 316.200, 011.200)
#      │   ├── test_tube_2_15         Tube                Coordinate(328.000, 335.000, 011.200)
#      │
# (15) ├── tube_carrier_3             TecanTubeCarrier    Coordinate(350.000, 038.000, 000.000)
#      │   ├── test_tube_3_0          Tube                Coordinate(353.000, 053.000, 011.200)
#      │   ├── test_tube_3_1          Tube                Coordinate(353.000, 071.800, 011.200)
#      │   ├── test_tube_3_2          Tube                Coordinate(353.000, 090.600, 011.200)
#      │   ├── test_tube_3_3          Tube                Coordinate(353.000, 109.400, 011.200)
#      │   ├── test_tube_3_4          Tube                Coordinate(353.000, 128.200, 011.200)
#      │   ├── test_tube_3_5          Tube                Coordinate(353.000, 147.000, 011.200)
#      │   ├── test_tube_3_6          Tube                Coordinate(353.000, 165.800, 011.200)
#      │   ├── test_tube_3_7          Tube                Coordinate(353.000, 184.600, 011.200)
#      │   ├── test_tube_3_8          Tube                Coordinate(353.000, 203.400, 011.200)
#      │   ├── test_tube_3_9          Tube                Coordinate(353.000, 222.200, 011.200)
#      │   ├── test_tube_3_10         Tube                Coordinate(353.000, 241.000, 011.200)
#      │   ├── test_tube_3_11         Tube                Coordinate(353.000, 259.800, 011.200)
#      │   ├── test_tube_3_12         Tube                Coordinate(353.000, 278.600, 011.200)
#      │   ├── test_tube_3_13         Tube                Coordinate(353.000, 297.400, 011.200)
#      │   ├── test_tube_3_14         Tube                Coordinate(353.000, 316.200, 011.200)
#      │   ├── test_tube_3_15         Tube                Coordinate(353.000, 335.000, 011.200)
#      │
# (16) ├── tube_carrier_4             TecanTubeCarrier    Coordinate(375.000, 038.000, 000.000)
#      │   ├── test_tube_4_0          Tube                Coordinate(378.000, 053.000, 011.200)
#      │   ├── test_tube_4_1          Tube                Coordinate(378.000, 071.800, 011.200)
#      │   ├── test_tube_4_2          Tube                Coordinate(378.000, 090.600, 011.200)
#      │   ├── test_tube_4_3          Tube                Coordinate(378.000, 109.400, 011.200)
#      │   ├── test_tube_4_4          Tube                Coordinate(378.000, 128.200, 011.200)
#      │   ├── test_tube_4_5          Tube                Coordinate(378.000, 147.000, 011.200)
#      │   ├── test_tube_4_6          Tube                Coordinate(378.000, 165.800, 011.200)
#      │   ├── test_tube_4_7          Tube                Coordinate(378.000, 184.600, 011.200)
#      │   ├── test_tube_4_8          Tube                Coordinate(378.000, 203.400, 011.200)
#      │   ├── test_tube_4_9          Tube                Coordinate(378.000, 222.200, 011.200)
#      │   ├── test_tube_4_10         Tube                Coordinate(378.000, 241.000, 011.200)
#      │   ├── test_tube_4_11         Tube                Coordinate(378.000, 259.800, 011.200)
#      │   ├── test_tube_4_12         Tube                Coordinate(378.000, 278.600, 011.200)
#      │   ├── test_tube_4_13         Tube                Coordinate(378.000, 297.400, 011.200)
#      │   ├── test_tube_4_14         Tube                Coordinate(378.000, 316.200, 011.200)
#      │   ├── test_tube_4_15         Tube                Coordinate(378.000, 335.000, 011.200)
#      │
# (17) ├── tube_carrier_5             TecanTubeCarrier    Coordinate(400.000, 038.000, 000.000)
#      │   ├── test_tube_5_0          Tube                Coordinate(403.000, 053.000, 011.200)
#      │   ├── test_tube_5_1          Tube                Coordinate(403.000, 071.800, 011.200)
#      │   ├── test_tube_5_2          Tube                Coordinate(403.000, 090.600, 011.200)
#      │   ├── test_tube_5_3          Tube                Coordinate(403.000, 109.400, 011.200)
#      │   ├── test_tube_5_4          Tube                Coordinate(403.000, 128.200, 011.200)
#      │   ├── test_tube_5_5          Tube                Coordinate(403.000, 147.000, 011.200)
#      │   ├── test_tube_5_6          Tube                Coordinate(403.000, 165.800, 011.200)
#      │   ├── test_tube_5_7          Tube                Coordinate(403.000, 184.600, 011.200)
#      │   ├── test_tube_5_8          Tube                Coordinate(403.000, 203.400, 011.200)
#      │   ├── test_tube_5_9          Tube                Coordinate(403.000, 222.200, 011.200)
#      │   ├── test_tube_5_10         Tube                Coordinate(403.000, 241.000, 011.200)
#      │   ├── test_tube_5_11         Tube                Coordinate(403.000, 259.800, 011.200)
#      │   ├── test_tube_5_12         Tube                Coordinate(403.000, 278.600, 011.200)
#      │   ├── test_tube_5_13         Tube                Coordinate(403.000, 297.400, 011.200)
#      │   ├── test_tube_5_14         Tube                Coordinate(403.000, 316.200, 011.200)
#      │   ├── test_tube_5_15         Tube                Coordinate(403.000, 335.000, 011.200)
#      │
# (18) ├── tube_carrier_6             TecanTubeCarrier    Coordinate(425.000, 038.000, 000.000)
#      │   ├── test_tube_6_0          Tube                Coordinate(428.000, 053.000, 011.200)
#      │   ├── test_tube_6_1          Tube                Coordinate(428.000, 071.800, 011.200)
#      │   ├── test_tube_6_2          Tube                Coordinate(428.000, 090.600, 011.200)
#      │   ├── test_tube_6_3          Tube                Coordinate(428.000, 109.400, 011.200)
#      │   ├── test_tube_6_4          Tube                Coordinate(428.000, 128.200, 011.200)
#      │   ├── test_tube_6_5          Tube                Coordinate(428.000, 147.000, 011.200)
#      │   ├── test_tube_6_6          Tube                Coordinate(428.000, 165.800, 011.200)
#      │   ├── test_tube_6_7          Tube                Coordinate(428.000, 184.600, 011.200)
#      │   ├── test_tube_6_8          Tube                Coordinate(428.000, 203.400, 011.200)
#      │   ├── test_tube_6_9          Tube                Coordinate(428.000, 222.200, 011.200)
#      │   ├── test_tube_6_10         Tube                Coordinate(428.000, 241.000, 011.200)
#      │   ├── test_tube_6_11         Tube                Coordinate(428.000, 259.800, 011.200)
#      │   ├── test_tube_6_12         Tube                Coordinate(428.000, 278.600, 011.200)
#      │   ├── test_tube_6_13         Tube                Coordinate(428.000, 297.400, 011.200)
#      │   ├── test_tube_6_14         Tube                Coordinate(428.000, 316.200, 011.200)
#      │   ├── test_tube_6_15         Tube                Coordinate(428.000, 335.000, 011.200)
#      │
# (19) ├── tube_carrier_7             TecanTubeCarrier    Coordinate(450.000, 038.000, 000.000)
#      │   ├── test_tube_7_0          Tube                Coordinate(453.000, 053.000, 011.200)
#      │   ├── test_tube_7_1          Tube                Coordinate(453.000, 071.800, 011.200)
#      │   ├── test_tube_7_2          Tube                Coordinate(453.000, 090.600, 011.200)
#      │   ├── test_tube_7_3          Tube                Coordinate(453.000, 109.400, 011.200)
#      │   ├── test_tube_7_4          Tube                Coordinate(453.000, 128.200, 011.200)
#      │   ├── test_tube_7_5          Tube                Coordinate(453.000, 147.000, 011.200)
#      │   ├── test_tube_7_6          Tube                Coordinate(453.000, 165.800, 011.200)
#      │   ├── test_tube_7_7          Tube                Coordinate(453.000, 184.600, 011.200)
#      │   ├── test_tube_7_8          Tube                Coordinate(453.000, 203.400, 011.200)
#      │   ├── test_tube_7_9          Tube                Coordinate(453.000, 222.200, 011.200)
#      │   ├── test_tube_7_10         Tube                Coordinate(453.000, 241.000, 011.200)
#      │   ├── test_tube_7_11         Tube                Coordinate(453.000, 259.800, 011.200)
#      │   ├── test_tube_7_12         Tube                Coordinate(453.000, 278.600, 011.200)
#      │   ├── test_tube_7_13         Tube                Coordinate(453.000, 297.400, 011.200)
#      │   ├── test_tube_7_14         Tube                Coordinate(453.000, 316.200, 011.200)
#      │   ├── test_tube_7_15         Tube                Coordinate(453.000, 335.000, 011.200)
#      │
# (20) ├── tube_carrier_8             TecanTubeCarrier    Coordinate(475.000, 038.000, 000.000)
#      │   ├── test_tube_8_0          Tube                Coordinate(478.000, 053.000, 011.200)
#      │   ├── test_tube_8_1          Tube                Coordinate(478.000, 071.800, 011.200)
#      │   ├── test_tube_8_2          Tube                Coordinate(478.000, 090.600, 011.200)
#      │   ├── test_tube_8_3          Tube                Coordinate(478.000, 109.400, 011.200)
#      │   ├── test_tube_8_4          Tube                Coordinate(478.000, 128.200, 011.200)
#      │   ├── test_tube_8_5          Tube                Coordinate(478.000, 147.000, 011.200)
#      │   ├── test_tube_8_6          Tube                Coordinate(478.000, 165.800, 011.200)
#      │   ├── test_tube_8_7          Tube                Coordinate(478.000, 184.600, 011.200)
#      │   ├── test_tube_8_8          Tube                Coordinate(478.000, 203.400, 011.200)
#      │   ├── test_tube_8_9          Tube                Coordinate(478.000, 222.200, 011.200)
#      │   ├── test_tube_8_10         Tube                Coordinate(478.000, 241.000, 011.200)
#      │   ├── test_tube_8_11         Tube                Coordinate(478.000, 259.800, 011.200)
#      │   ├── test_tube_8_12         Tube                Coordinate(478.000, 278.600, 011.200)
#      │   ├── test_tube_8_13         Tube                Coordinate(478.000, 297.400, 011.200)
#      │   ├── test_tube_8_14         Tube                Coordinate(478.000, 316.200, 011.200)
#      │   ├── test_tube_8_15         Tube                Coordinate(478.000, 335.000, 011.200)
#      │
# (22) ├── Flat Carrier 1             TecanPlateCarrier   Coordinate(513.000, 061.000, 000.000)
#      │   ├── well_0                 TecanPlate          Coordinate(540.400, 147.600, 006.000)
#      │   ├── well_1                 TecanPlate          Coordinate(540.400, 243.600, 006.000)
#      │   ├── well_2                 TecanPlate          Coordinate(540.400, 339.600, 006.000)
#      │
# (28) ├── Flat Carrier 2             TecanPlateCarrier   Coordinate(663.000, 061.000, 000.000)
#      │   ├── well_3                 TecanPlate          Coordinate(690.400, 147.600, 006.000)
#      │   ├── well_4                 TecanPlate          Coordinate(690.400, 243.600, 006.000)
#      │   ├── well_5                 TecanPlate          Coordinate(690.400, 339.600, 006.000)
#      │
# (38) ├── Wash Station               TecanTipCarrier     Coordinate(912.500, 007.500, 000.000)
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │
# (41) ├── Disposable Tip Carrier     TecanTipCarrier     Coordinate(988.000, -04.300, 000.000)
#      │   ├── tips_0                 TecanTipRack        Coordinate(1015.600, 141.300, 037.100)
#      │   ├── tips_1                 TecanTipRack        Coordinate(1015.600, 241.300, 037.100)
#      │   ├── tips_2                 TecanTipRack        Coordinate(1015.600, 341.300, 037.100)
#      │
# (48) ├── Centrifuge Bucket Carrier  TecanPlateCarrier   Coordinate(1164.000, 016.000, 000.000)
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>
#      │
# (61) ├── Regrip                     TecanPlateCarrier   Coordinate(1488.000, 053.700, 000.000)
#      │   ├── <empty>
#      │   ├── <empty>
#      │   ├── <empty>

# %%
# await lh.move_resource(lh.get_resource('tube0'), tube_carrier[0])
from pylabrobot.liquid_handling.backends.tecan.EVO_backend import EVOBackend, PnP, LiHa, RoMa
evo = EVOBackend([PnP, LiHa, RoMa])

tube_carrier = lh.get_resource("tube_carrier_0")
evo.get_system_coordinates(tube_carrier[0])
# Out:
# Coordinate(x=278.0, y=279.0, z=11.2)

# %%
await lh.move_resource(lh.get_resource('well_5'), lh.get_resource('Centrifuge Bucket Carrier-3'))
